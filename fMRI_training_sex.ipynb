# %%
import os
import time
from datetime import datetime

from utils import *
from model.MLP import *

import numpy as np
import nibabel as nib
import matplotlib.pyplot as plt
import pandas as pd
from scipy.stats import pearsonr


import torch
import torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.utils.tensorboard import SummaryWriter

from torchsummary import summary


os.environ["CUDA_VISIBLE_DEVICES"] = ""
device = torch.device('cuda' if torch.cuda.is_available() else "cpu")
print(device)
print(torch.cuda.device_count())

input_sizes = {'15':105,
                '25':300,
                '50':1225,
                '100':4950,
                '200':19900,
                '300':44850
                }
# Out:
# cpu
# 0

# %%
df = pd.read_csv(os.path.join('./data/netmats/ICA50/connectivity_ICA50.csv'))
df
# Out:
#             1       2         3        4        5          6        7  \
# 0     -4.2163  22.394  19.94200 -16.8410 -3.49510   2.673600   9.0675
# 1    -10.0030  26.172  13.19600 -10.2010 -6.37360  -0.668310   9.0020
# 2    -12.8890  33.142  27.21000 -16.8910  5.80820 -19.186000  17.7220
# 3    -32.9700  31.320  29.47100  -5.3898  0.17415  -6.101400  13.0740
# 4    -14.3080  20.883  22.14900 -14.0430 -3.23670  -0.041191  12.5720
# ...       ...     ...       ...      ...      ...        ...      ...
# 998  -15.0010  30.550  32.84300 -11.5010  1.51470  -8.253500  14.8260
# 999  -16.8270  23.803  22.94700 -18.8330 -0.86845 -13.010000  12.9180
# 1000  -1.5473  11.996  14.64600  -8.9126 -6.07010   1.752300   2.3664
# 1001 -11.4170  18.059  12.41900 -13.9420  6.87130  -3.199000  10.6190
# 1002  -5.3479  16.196  -0.62081  -8.9622 -4.70570   1.507400   5.3957
#
#             8        9       10  ...      2298    2299     2347     2348  \
# 0     8.29000 -16.2850 -0.77709  ...  0.879030  6.6539  6.11060  0.26746
# 1     2.14640  -9.0834 -4.57020  ... -1.235500  1.2009  0.54869  1.11700
# 2    -6.29380  -9.8391  5.91700  ...  3.625400  5.5734  1.74650  2.43660
# 3    -0.97555  -2.3570  0.90103  ...  0.007258  3.1784  3.52920 -0.77047
# 4     2.70090  -9.3794 -4.42780  ... -1.618800  2.6547  0.75150 -0.30357
# ...       ...      ...      ...  ...       ...     ...      ...      ...
# 998   2.38830  -7.7150 -0.72109  ... -0.629590  3.5904  2.02480  0.19548
# 999  -7.47800 -13.9710  0.88499  ...  1.912900  1.4380  1.93220  1.81780
# 1000  1.12080  -8.6367 -1.05050  ... -2.351500  2.0370 -0.28485 -0.53574
# 1001 -5.19770  -2.3150 -3.33060  ... -1.628700  2.0194  1.88290 -1.03650
# 1002  8.58890 -10.9820 -2.62020  ... -0.731430  2.4767  1.45140  1.08740
#
#           2349      2398     2399     2449  sex  fluid_intelligence
# 0     3.417400  0.149230  4.78100  0.96299    0                20.0
# 1    -0.262750  0.658960  1.38720  0.19027    1                17.0
# 2     1.856400 -0.281460  0.23664  6.61680    0                 7.0
# 3     1.737600 -0.002256  0.76007  0.67508    0                23.0
# 4    -0.520730  3.147400  3.23960  1.95650    1                11.0
# ...        ...       ...      ...      ...  ...                 ...
# 998   2.554400 -0.968720  1.63390  2.02180    1                21.0
# 999   0.044716  1.082600  1.18370  1.32360    0                14.0
# 1000  1.072000  0.803140 -0.54247 -0.84915    1                21.0
# 1001 -0.275030  0.958400  1.66140  2.86820    0                20.0
# 1002 -0.977820  1.811300  0.87160 -1.06340    1                20.0
#
# [1003 rows x 1227 columns]

# %%
nbr_components= 50
data_path = '/home/sd20/workspace/data/HCP/'

loader = dataLoaderICA(data_path = './data/netmats',
                        nbr_components = nbr_components,
                        batch_size = 32,
                        num_workers = 8,
                        label ='sex',)

dataloaders = loader.getDataLoaders()
# Out:
# shape X train (802, 1225) , y train (802,)
# shape X val (201, 1225) , y val (201,)

# %%
for i, data in enumerate(dataloaders['train']):
    print(i)
    print(data[0].shape, data[1].shape)
    break
# Out:
# 0
# torch.Size([32, 1225]) torch.Size([32])

# %%
net = MLP(input_size=300,
          hidden_size=[16],
          dropout=0.5)

net
# Out:
# MLP(
#   (fc_layers): ModuleDict(
#     (fc_layer_0): Linear(in_features=300, out_features=16, bias=False)
#   )
#   (fc_class): Linear(in_features=16, out_features=1, bias=True)
#   (dropout): Dropout(p=0.5, inplace=False)
#   (relu): ReLU()
# )

# %% [markdown]
# #### Optimiser, Loss and Training parameters

# %%
nbr_components = 50

input_size = input_sizes[str(nbr_components)]
hidden_size =[16]
dropout = 0.5
batch_size = 64


n_epochs = 500
lr = 1e-4

# %%
# loaders
loader = dataLoaderICA(data_path = './data/netmats',
                        nbr_components = nbr_components,
                        batch_size = batch_size,
                        num_workers = 8,
                        label ='sex',)


dataloaders = loader.getDataLoaders()

# network
net = MLP(input_size,
          hidden_size,
          dropout)

#loss
loss = nn.BCEWithLogitsLoss()

#optimiser
optimiser = torch.optim.Adam(net.parameters(), lr=lr)

#lr scheduler

#metrics to store during training
metrics = {'loss_train': [], 'loss_valid': [], 
           'acc_train': [], 'acc_valid':[]}
# Out:
# shape X train (802, 1225) , y train (802,)
# shape X val (201, 1225) , y val (201,)

# %% [markdown]
# ### logging
#
# 1) save parameters
#
# 2) create folder for log tensorboard

# %%
path = '/home/sd20/workspace/spatio-temporal-fmri-analysis'
date = datetime.today().strftime('%Y-%m-%d')
print(date)

# folder date
folder_to_save_model = os.path.join(path,'logs', date)
try:
    os.mkdir(folder_to_save_model)
    print('Creating folder: {}'.format(folder_to_save_model))
except OSError:
    print('folder already exist: {}'.format(folder_to_save_model))

date = datetime.today().strftime('%H:%M:%S')
print(date)

# folder ICA
folder_to_save_model = os.path.join(folder_to_save_model,'ICA_{}'.format(nbr_components))

# folder time
folder_to_save_model = os.path.join(folder_to_save_model,date)
try:
    os.mkdir(folder_to_save_model)
    print('Creating folder: {}'.format(folder_to_save_model))
except OSError:
    print('folder already exist: {}'.format(folder_to_save_model))




# tensorboard 
writer = SummaryWriter(log_dir=folder_to_save_model)
# Out:
# 2021-06-07
# folder already exist: /home/sd20/workspace/spatio-temporal-fmri-analysis/logs/2021-06-07
# 10:54:00
# Creating folder: /home/sd20/workspace/spatio-temporal-fmri-analysis/logs/2021-06-07/ICA_50/10:54:00

# %%
f = open(os.path.join(folder_to_save_model,'log.txt'),"w+")

# logging the hyperparameters

f.write("Batch size: {} \n".format(batch_size))
f.write("Epoch: {} \n".format(n_epochs))
f.write("Learning rate: {} \n".format(lr))
f.write("Optimiser: {} \n".format(optimiser))
f.close()

# %%
writer.add_graph(net, torch.rand(batch_size,input_sizes[str(nbr_components)]))

# %%
net
# Out:
# MLP(
#   (fc_layers): ModuleDict(
#     (fc_layer_0): Linear(in_features=1225, out_features=16, bias=True)
#   )
#   (fc_class): Linear(in_features=16, out_features=1, bias=True)
#   (dropout): Dropout(p=0.5, inplace=False)
#   (relu): ReLU()
# )

# %% [markdown]
# #### TRAINING & VALIDATION LOOPS

# %%
best_train_epoch = 0.0
best_val_epoch = 0.0

for epoch in range(0, n_epochs):
    print('#'*50)

    # Print learning rate for each epoch -- good for when you have a LR scheduler
    #scheduler.step()
    #lr = optim.param_groups[0]['lr']
    #print('lr = %.7f' % lr)

    # Save time to calculate how long it took
    start_time = time.time()

    # Append emtpy list so that each epoch has a list of valuess
    for key_ in metrics.keys():
        metrics[key_].append([])

    predictions_val = []
    gt_val =[]
    epoch_acc_val = []
    epoch_acc_train = []


    # Go through each phase TRAIN/VALID
    #####################################################  
    for phase in ['train','valid']:

        total_correct = 0.0
        total_size = 0.0

        # Go through each data point in either train or validation
        #####################################################  
        for i, (inputs, labels) in enumerate(dataloaders[phase]):

            
            # Calculates step
            length_dataloader = len(dataloaders[phase])
            step = epoch * length_dataloader + i + 1

            # Fetch batch of data
            ##################################################
            # Image data
            inputs = inputs.to(device)
            
            # Label data
            lab_gt = labels.to(device)

            # TRAIN
            ##################################################
            if phase == 'train':

                optimiser.zero_grad()

                outputs =  net(inputs).squeeze()  

                current_loss =  loss(outputs,labels) 

                #####
                metrics['loss_train'][-1].append(current_loss.item())
                writer.add_scalar('loss/train', current_loss.item(), epoch*length_dataloader+i)

                predicted = torch.round(torch.nn.functional.sigmoid(outputs))
                correct_batch = (predicted == lab_gt).sum().item()

                total_correct += correct_batch
                total_size += lab_gt.shape[0]

                accuracy_batch = correct_batch / lab_gt.shape[0]
                epoch_acc_train.append(accuracy_batch*100.)
                metrics['acc_train'][-1].append(accuracy_batch * 100.)     
                writer.add_scalar('accuracy/train', accuracy_batch * 100., epoch*length_dataloader+i)

                #####
                current_loss.backward() 

                optimiser.step()
        
            if phase == 'valid':

                net.eval()

                with torch.no_grad():

                    outputs_val = net(inputs).squeeze()

                    current_loss = loss(outputs_val, lab_gt)

                    metrics['loss_valid'][-1].append(current_loss.item())
                    writer.add_scalar('loss/val', current_loss.item(), epoch*length_dataloader+i)

                    predicted_val = torch.round(torch.nn.functional.sigmoid(outputs_val))
                    predictions_val = predictions_val + list(predicted_val.numpy())
                    gt_val = gt_val + list(lab_gt.numpy())

                    correct_batch = (predicted_val == lab_gt).sum().item()
                    total_correct += correct_batch
                    total_size += lab_gt.shape[0]

                    accuracy_batch = correct_batch / lab_gt.shape[0]
                    epoch_acc_val.append(accuracy_batch*100.)
                    metrics['acc_valid'][-1].append(accuracy_batch * 100.)  
                    writer.add_scalar('accuracy/val', accuracy_batch * 100., epoch*length_dataloader+i)   

        if phase =='valid':
            if np.mean(epoch_acc_val)>best_val_epoch:
                best_val_epoch=np.mean(epoch_acc_val)
            writer.add_scalar('accuracy_best_epoch/val',best_val_epoch, epoch)   
        if phase =='train':
            if np.mean(epoch_acc_train)>best_train_epoch:
                best_train_epoch=np.mean(epoch_acc_train)
            writer.add_scalar('accuracy_best_epoch/train',best_train_epoch, epoch)   


        # PRINT STATS
        ###################################################
        print(total_correct, total_size)
        accuracy = total_correct / total_size

        time_elapsed = time.time() - start_time
        print("%s Epoch: %3d | Acc:  %3d| Loss:%.4e | %.0fm %.2fs" %
                (phase.upper(), epoch, accuracy * 100,
                current_loss.item(), time_elapsed // 60, time_elapsed % 60))

        print('')
# Out:
# ##################################################
# 394.0 802.0
# TRAIN Epoch:   0 | Acc:   49| Loss:7.1379e-01 | 0m 0.32s
#
# 108.0 201.0
# VALID Epoch:   0 | Acc:   53| Loss:7.9024e-01 | 0m 0.70s
#
# ##################################################
# 459.0 802.0
# TRAIN Epoch:   1 | Acc:   57| Loss:6.6961e-01 | 0m 0.40s
#
# 111.0 201.0
# VALID Epoch:   1 | Acc:   55| Loss:7.5191e-01 | 0m 0.76s
#
# ##################################################
# 466.0 802.0
# TRAIN Epoch:   2 | Acc:   58| Loss:6.5320e-01 | 0m 0.37s
#
# 118.0 201.0
# VALID Epoch:   2 | Acc:   58| Loss:7.2714e-01 | 0m 0.71s
#
# ##################################################
# 502.0 802.0
# TRAIN Epoch:   3 | Acc:   62| Loss:6.4990e-01 | 0m 0.39s
#
# 128.0 201.0
# VALID Epoch:   3 | Acc:   63| Loss:7.3234e-01 | 0m 0.73s
#
# ##################################################
# 524.0 802.0
# TRAIN Epoch:   4 | Acc:   65| Loss:6.2282e-01 | 0m 0.36s
#
# 137.0 201.0
# VALID Epoch:   4 | Acc:   68| Loss:6.6014e-01 | 0m 0.71s
#
# ##################################################
# 570.0 802.0
# TRAIN Epoch:   5 | Acc:   71| Loss:5.6196e-01 | 0m 0.37s
#
# 142.0 201.0
# VALID Epoch:   5 | Acc:   70| Loss:6.1920e-01 | 0m 0.70s
#
# ##################################################
# 595.0 802.0
# TRAIN Epoch:   6 | Acc:   74| Loss:5.1036e-01 | 0m 0.38s
#
# 149.0 201.0
# VALID Epoch:   6 | Acc:   74| Loss:5.6956e-01 | 0m 0.71s
#
# ##################################################
# 637.0 802.0
# TRAIN Epoch:   7 | Acc:   79| Loss:5.8739e-01 | 0m 0.33s
#
# 158.0 201.0
# VALID Epoch:   7 | Acc:   78| Loss:4.9469e-01 | 0m 0.63s
#
# ##################################################
# 650.0 802.0
# TRAIN Epoch:   8 | Acc:   81| Loss:4.5828e-01 | 0m 0.38s
#
# 160.0 201.0
# VALID Epoch:   8 | Acc:   79| Loss:3.9599e-01 | 0m 0.68s
#
# ##################################################
# 677.0 802.0
# TRAIN Epoch:   9 | Acc:   84| Loss:4.5639e-01 | 0m 0.33s
#
# 164.0 201.0
# VALID Epoch:   9 | Acc:   81| Loss:3.5525e-01 | 0m 0.66s
#
# ##################################################
# 692.0 802.0
# TRAIN Epoch:  10 | Acc:   86| Loss:4.0071e-01 | 0m 0.41s
#
# 168.0 201.0
# VALID Epoch:  10 | Acc:   83| Loss:3.2787e-01 | 0m 0.74s
#
# ##################################################
# 707.0 802.0
# TRAIN Epoch:  11 | Acc:   88| Loss:3.3065e-01 | 0m 0.34s
#
# 170.0 201.0
# VALID Epoch:  11 | Acc:   84| Loss:3.0729e-01 | 0m 0.68s
#
# ##################################################
# 709.0 802.0
# TRAIN Epoch:  12 | Acc:   88| Loss:3.6850e-01 | 0m 0.35s
#
# 171.0 201.0
# VALID Epoch:  12 | Acc:   85| Loss:2.8215e-01 | 0m 0.69s
#
# ##################################################
# 713.0 802.0
# TRAIN Epoch:  13 | Acc:   88| Loss:3.2810e-01 | 0m 0.34s
#
# 175.0 201.0
# VALID Epoch:  13 | Acc:   87| Loss:2.6767e-01 | 0m 0.65s
#
# ##################################################
# 715.0 802.0
# TRAIN Epoch:  14 | Acc:   89| Loss:2.6054e-01 | 0m 0.35s
#
# 175.0 201.0
# VALID Epoch:  14 | Acc:   87| Loss:2.5543e-01 | 0m 0.66s
#
# ##################################################
# 731.0 802.0
# TRAIN Epoch:  15 | Acc:   91| Loss:2.8598e-01 | 0m 0.37s
#
# 178.0 201.0
# VALID Epoch:  15 | Acc:   88| Loss:2.4523e-01 | 0m 0.73s
#
# ##################################################
# 730.0 802.0
# TRAIN Epoch:  16 | Acc:   91| Loss:2.5196e-01 | 0m 0.37s
#
# 180.0 201.0
# VALID Epoch:  16 | Acc:   89| Loss:2.4368e-01 | 0m 0.69s
#
# ##################################################
# 736.0 802.0
# TRAIN Epoch:  17 | Acc:   91| Loss:2.8693e-01 | 0m 0.32s
#
# 183.0 201.0
# VALID Epoch:  17 | Acc:   91| Loss:2.3939e-01 | 0m 0.65s
#
# ##################################################
# 745.0 802.0
# TRAIN Epoch:  18 | Acc:   92| Loss:2.8878e-01 | 0m 0.33s
#
# 181.0 201.0
# VALID Epoch:  18 | Acc:   90| Loss:2.2978e-01 | 0m 0.72s
#
# ##################################################
# 749.0 802.0
# TRAIN Epoch:  19 | Acc:   93| Loss:2.3228e-01 | 0m 0.32s
#
# 178.0 201.0
# VALID Epoch:  19 | Acc:   88| Loss:2.2327e-01 | 0m 0.64s
#
# ##################################################
# 757.0 802.0
# TRAIN Epoch:  20 | Acc:   94| Loss:1.6331e-01 | 0m 0.37s
#
# 179.0 201.0
# VALID Epoch:  20 | Acc:   89| Loss:2.3008e-01 | 0m 0.71s
#
# ##################################################
# 748.0 802.0
# TRAIN Epoch:  21 | Acc:   93| Loss:2.2847e-01 | 0m 0.32s
#
# 177.0 201.0
# VALID Epoch:  21 | Acc:   88| Loss:2.3462e-01 | 0m 0.69s
#
# ##################################################
# 759.0 802.0
# TRAIN Epoch:  22 | Acc:   94| Loss:1.4149e-01 | 0m 0.35s
#
# 180.0 201.0
# VALID Epoch:  22 | Acc:   89| Loss:2.2232e-01 | 0m 0.67s
#
# ##################################################
# 762.0 802.0
# TRAIN Epoch:  23 | Acc:   95| Loss:2.0707e-01 | 0m 0.35s
#
# 177.0 201.0
# VALID Epoch:  23 | Acc:   88| Loss:2.2646e-01 | 0m 0.68s
#
# ##################################################
# 762.0 802.0
# TRAIN Epoch:  24 | Acc:   95| Loss:2.2408e-01 | 0m 0.34s
#
# 183.0 201.0
# VALID Epoch:  24 | Acc:   91| Loss:2.1513e-01 | 0m 0.67s
#
# ##################################################
# 765.0 802.0
# TRAIN Epoch:  25 | Acc:   95| Loss:2.2863e-01 | 0m 0.33s
#
# 180.0 201.0
# VALID Epoch:  25 | Acc:   89| Loss:2.0799e-01 | 0m 0.67s
#
# ##################################################
# 769.0 802.0
# TRAIN Epoch:  26 | Acc:   95| Loss:2.3435e-01 | 0m 0.34s
#
# 179.0 201.0
# VALID Epoch:  26 | Acc:   89| Loss:2.1637e-01 | 0m 0.65s
#
# ##################################################
# 771.0 802.0
# TRAIN Epoch:  27 | Acc:   96| Loss:2.1668e-01 | 0m 0.35s
#
# 181.0 201.0
# VALID Epoch:  27 | Acc:   90| Loss:2.1071e-01 | 0m 0.68s
#
# ##################################################
# 769.0 802.0
# TRAIN Epoch:  28 | Acc:   95| Loss:2.3870e-01 | 0m 0.37s
#
# 182.0 201.0
# VALID Epoch:  28 | Acc:   90| Loss:1.9851e-01 | 0m 0.71s
#
# ##################################################
# 776.0 802.0
# TRAIN Epoch:  29 | Acc:   96| Loss:2.9135e-01 | 0m 0.35s
#
# 183.0 201.0
# VALID Epoch:  29 | Acc:   91| Loss:2.0367e-01 | 0m 0.74s
#
# ##################################################
# 776.0 802.0
# TRAIN Epoch:  30 | Acc:   96| Loss:1.1525e-01 | 0m 0.37s
#
# 181.0 201.0
# VALID Epoch:  30 | Acc:   90| Loss:2.0348e-01 | 0m 0.67s
#
# ##################################################
# 778.0 802.0
# TRAIN Epoch:  31 | Acc:   97| Loss:1.2645e-01 | 0m 0.35s
#
# 181.0 201.0
# VALID Epoch:  31 | Acc:   90| Loss:2.0667e-01 | 0m 0.72s
#
# ##################################################
# 779.0 802.0
# TRAIN Epoch:  32 | Acc:   97| Loss:1.2590e-01 | 0m 0.36s
#
# 180.0 201.0
# VALID Epoch:  32 | Acc:   89| Loss:2.1802e-01 | 0m 0.72s
#
# ##################################################
# 781.0 802.0
# TRAIN Epoch:  33 | Acc:   97| Loss:1.4264e-01 | 0m 0.36s
#
# 182.0 201.0
# VALID Epoch:  33 | Acc:   90| Loss:2.0007e-01 | 0m 0.67s
#
# ##################################################
# 784.0 802.0
# TRAIN Epoch:  34 | Acc:   97| Loss:1.2811e-01 | 0m 0.33s
#
# 183.0 201.0
# VALID Epoch:  34 | Acc:   91| Loss:2.1438e-01 | 0m 0.68s
#
# ##################################################
# 780.0 802.0
# TRAIN Epoch:  35 | Acc:   97| Loss:1.3877e-01 | 0m 0.33s
#
# 181.0 201.0
# VALID Epoch:  35 | Acc:   90| Loss:2.0246e-01 | 0m 0.64s
#
# ##################################################
# 786.0 802.0
# TRAIN Epoch:  36 | Acc:   98| Loss:1.3579e-01 | 0m 0.39s
#
# 182.0 201.0
# VALID Epoch:  36 | Acc:   90| Loss:2.1349e-01 | 0m 0.74s
#
# ##################################################
# 786.0 802.0
# TRAIN Epoch:  37 | Acc:   98| Loss:9.5609e-02 | 0m 0.36s
#
# 184.0 201.0
# VALID Epoch:  37 | Acc:   91| Loss:1.9433e-01 | 0m 0.69s
#
# ##################################################
# 792.0 802.0
# TRAIN Epoch:  38 | Acc:   98| Loss:8.8092e-02 | 0m 0.36s
#
# 179.0 201.0
# VALID Epoch:  38 | Acc:   89| Loss:2.1593e-01 | 0m 0.69s
#
# ##################################################
# 788.0 802.0
# TRAIN Epoch:  39 | Acc:   98| Loss:1.1375e-01 | 0m 0.33s
#
# 181.0 201.0
# VALID Epoch:  39 | Acc:   90| Loss:1.8881e-01 | 0m 0.69s
#
# ##################################################
# 792.0 802.0
# TRAIN Epoch:  40 | Acc:   98| Loss:8.1414e-02 | 0m 0.34s
#
# 183.0 201.0
# VALID Epoch:  40 | Acc:   91| Loss:1.9837e-01 | 0m 0.72s
#
# ##################################################
# 790.0 802.0
# TRAIN Epoch:  41 | Acc:   98| Loss:9.6113e-02 | 0m 0.37s
#
# 181.0 201.0
# VALID Epoch:  41 | Acc:   90| Loss:1.8679e-01 | 0m 0.74s
#
# ##################################################
# 793.0 802.0
# TRAIN Epoch:  42 | Acc:   98| Loss:1.3429e-01 | 0m 0.33s
#
# 183.0 201.0
# VALID Epoch:  42 | Acc:   91| Loss:1.9792e-01 | 0m 0.68s
#
# ##################################################
# 793.0 802.0
# TRAIN Epoch:  43 | Acc:   98| Loss:1.1520e-01 | 0m 0.32s
#
# 181.0 201.0
# VALID Epoch:  43 | Acc:   90| Loss:1.8136e-01 | 0m 0.67s
#
# ##################################################
# 796.0 802.0
# TRAIN Epoch:  44 | Acc:   99| Loss:7.9398e-02 | 0m 0.37s
#
# 183.0 201.0
# VALID Epoch:  44 | Acc:   91| Loss:1.9384e-01 | 0m 0.71s
#
# ##################################################
# 795.0 802.0
# TRAIN Epoch:  45 | Acc:   99| Loss:9.1074e-02 | 0m 0.32s
#
# 183.0 201.0
# VALID Epoch:  45 | Acc:   91| Loss:1.9570e-01 | 0m 0.66s
#
# ##################################################
# 797.0 802.0
# TRAIN Epoch:  46 | Acc:   99| Loss:1.1372e-01 | 0m 0.35s
#
# 181.0 201.0
# VALID Epoch:  46 | Acc:   90| Loss:1.7825e-01 | 0m 0.69s
#
# ##################################################
# 796.0 802.0
# TRAIN Epoch:  47 | Acc:   99| Loss:7.1118e-02 | 0m 0.36s
#
# 183.0 201.0
# VALID Epoch:  47 | Acc:   91| Loss:1.8846e-01 | 0m 0.72s
#
# ##################################################
# 795.0 802.0
# TRAIN Epoch:  48 | Acc:   99| Loss:6.6474e-02 | 0m 0.39s
#
# 183.0 201.0
# VALID Epoch:  48 | Acc:   91| Loss:2.1640e-01 | 0m 0.72s
#
# ##################################################
# 794.0 802.0
# TRAIN Epoch:  49 | Acc:   99| Loss:1.0640e-01 | 0m 0.38s
#
# 183.0 201.0
# VALID Epoch:  49 | Acc:   91| Loss:1.9175e-01 | 0m 0.70s
#
# ##################################################
# 797.0 802.0
# TRAIN Epoch:  50 | Acc:   99| Loss:1.1620e-01 | 0m 0.34s
#
# 182.0 201.0
# VALID Epoch:  50 | Acc:   90| Loss:1.7651e-01 | 0m 0.64s
#
# ##################################################
# 799.0 802.0
# TRAIN Epoch:  51 | Acc:   99| Loss:8.7630e-02 | 0m 0.34s
#
# 185.0 201.0
# VALID Epoch:  51 | Acc:   92| Loss:2.1573e-01 | 0m 0.68s
#
# ##################################################
# 798.0 802.0
# TRAIN Epoch:  52 | Acc:   99| Loss:7.7383e-02 | 0m 0.32s
#
# 183.0 201.0
# VALID Epoch:  52 | Acc:   91| Loss:2.0882e-01 | 0m 0.66s
#
# ##################################################
# 798.0 802.0
# TRAIN Epoch:  53 | Acc:   99| Loss:6.5492e-02 | 0m 0.36s
#
# 182.0 201.0
# VALID Epoch:  53 | Acc:   90| Loss:1.8976e-01 | 0m 0.71s
#
# ##################################################
# 800.0 802.0
# TRAIN Epoch:  54 | Acc:   99| Loss:5.6148e-02 | 0m 0.37s
#
# 182.0 201.0
# VALID Epoch:  54 | Acc:   90| Loss:1.8503e-01 | 0m 0.69s
#
# ##################################################
# 799.0 802.0
# TRAIN Epoch:  55 | Acc:   99| Loss:8.2647e-02 | 0m 0.40s
#
# 181.0 201.0
# VALID Epoch:  55 | Acc:   90| Loss:1.8803e-01 | 0m 0.72s
#
# ##################################################
# 798.0 802.0
# TRAIN Epoch:  56 | Acc:   99| Loss:5.9872e-02 | 0m 0.39s
#
# 185.0 201.0
# VALID Epoch:  56 | Acc:   92| Loss:2.2178e-01 | 0m 0.70s
#
# ##################################################
# 799.0 802.0
# TRAIN Epoch:  57 | Acc:   99| Loss:7.0605e-02 | 0m 0.34s
#
# 185.0 201.0
# VALID Epoch:  57 | Acc:   92| Loss:2.0696e-01 | 0m 0.67s
#
# ##################################################
# 801.0 802.0
# TRAIN Epoch:  58 | Acc:   99| Loss:6.2220e-02 | 0m 0.32s
#
# 185.0 201.0
# VALID Epoch:  58 | Acc:   92| Loss:1.9946e-01 | 0m 0.66s
#
# ##################################################
# 801.0 802.0
# TRAIN Epoch:  59 | Acc:   99| Loss:6.8394e-02 | 0m 0.35s
#
# 185.0 201.0
# VALID Epoch:  59 | Acc:   92| Loss:2.0469e-01 | 0m 0.69s
#
# ##################################################
# 801.0 802.0
# TRAIN Epoch:  60 | Acc:   99| Loss:6.7643e-02 | 0m 0.31s
#
# 182.0 201.0
# VALID Epoch:  60 | Acc:   90| Loss:1.9390e-01 | 0m 0.62s
#
# ##################################################
# 800.0 802.0
# TRAIN Epoch:  61 | Acc:   99| Loss:9.0006e-02 | 0m 0.33s
#
# 183.0 201.0
# VALID Epoch:  61 | Acc:   91| Loss:2.0616e-01 | 0m 0.65s
#
# ##################################################
# 801.0 802.0
# TRAIN Epoch:  62 | Acc:   99| Loss:2.8252e-02 | 0m 0.36s
#
# 181.0 201.0
# VALID Epoch:  62 | Acc:   90| Loss:1.8968e-01 | 0m 0.68s
#
# ##################################################
# 802.0 802.0
# TRAIN Epoch:  63 | Acc:  100| Loss:7.0583e-02 | 0m 0.33s
#
# 186.0 201.0
# VALID Epoch:  63 | Acc:   92| Loss:2.0645e-01 | 0m 0.66s
#
# ##################################################
# 802.0 802.0
# TRAIN Epoch:  64 | Acc:  100| Loss:4.9252e-02 | 0m 0.36s
#
# 185.0 201.0
# VALID Epoch:  64 | Acc:   92| Loss:2.4023e-01 | 0m 0.70s
#
# ##################################################
# 801.0 802.0
# TRAIN Epoch:  65 | Acc:   99| Loss:9.0260e-02 | 0m 0.32s
#
# 185.0 201.0
# VALID Epoch:  65 | Acc:   92| Loss:2.1020e-01 | 0m 0.64s
#
# ##################################################
# 801.0 802.0
# TRAIN Epoch:  66 | Acc:   99| Loss:7.8261e-02 | 0m 0.37s
#
# 185.0 201.0
# VALID Epoch:  66 | Acc:   92| Loss:2.0345e-01 | 0m 0.73s
#
# ##################################################
# 801.0 802.0
# TRAIN Epoch:  67 | Acc:   99| Loss:3.2861e-02 | 0m 0.37s
#
# 181.0 201.0
# VALID Epoch:  67 | Acc:   90| Loss:1.9175e-01 | 0m 0.72s
#
# ##################################################
# 801.0 802.0
# TRAIN Epoch:  68 | Acc:   99| Loss:4.8830e-02 | 0m 0.37s
#
# 186.0 201.0
# VALID Epoch:  68 | Acc:   92| Loss:2.1816e-01 | 0m 0.70s
#
# ##################################################
# 802.0 802.0
# TRAIN Epoch:  69 | Acc:  100| Loss:4.6881e-02 | 0m 0.39s
#
# 186.0 201.0
# VALID Epoch:  69 | Acc:   92| Loss:2.1186e-01 | 0m 0.70s
#
# ##################################################
# 802.0 802.0
# TRAIN Epoch:  70 | Acc:  100| Loss:4.6428e-02 | 0m 0.34s
#
# 185.0 201.0
# VALID Epoch:  70 | Acc:   92| Loss:2.0212e-01 | 0m 0.68s
#
# ##################################################
# 802.0 802.0
# TRAIN Epoch:  71 | Acc:  100| Loss:2.4085e-02 | 0m 0.35s
#
# 185.0 201.0
# VALID Epoch:
-02 | 0m 0.34s
#
# 186.0 201.0
# VALID Epoch: 130 | Acc:   92| Loss:2.5840e-01 | 0m 0.67s
#
# ##################################################
# 802.0 802.0
# TRAIN Epoch: 131 | Acc:  100| Loss:1.7180e-02 | 0m 0.34s
#
# 186.0 201.0
# VALID Epoch: 131 | Acc:   92| Loss:2.4746e-01 | 0m 0.66s
#
# ##################################################
# 802.0 802.0
# TRAIN Epoch: 132 | Acc:  100| Loss:1.1526e-02 | 0m 0.33s
#
# 185.0 201.0
# VALID Epoch: 132 | Acc:   92| Loss:2.4147e-01 | 0m 0.65s
#
# ##################################################
# 802.0 802.0
# TRAIN Epoch: 133 | Acc:  100| Loss:9.4177e-03 | 0m 0.37s
#
# 185.0 201.0
# VALID Epoch: 133 | Acc:   92| Loss:2.4962e-01 | 0m 0.69s
#
# ##################################################
# 802.0 802.0
# TRAIN Epoch: 134 | Acc:  100| Loss:1.2951e-02 | 0m 0.33s
#
# 186.0 201.0
# VALID Epoch: 134 | Acc:   92| Loss:2.6712e-01 | 0m 0.67s
#
# ##################################################
# 802.0 802.0
# TRAIN Epoch: 135 | Acc:  100| Loss:1.2975e-02 | 0m 0.34s
#
# 186.0 201.0
# VALID Epoch: 135 | Acc:   92| Loss:2.3906e-01 | 0m 0.64s
#
# ##################################################
# 802.0 802.0
# TRAIN Epoch: 136 | Acc:  100| Loss:9.0672e-03 | 0m 0.33s
#
# 186.0 201.0
# VALID Epoch: 136 | Acc:   92| Loss:2.5188e-01 | 0m 0.65s
#
# ##################################################
# 802.0 802.0
# TRAIN Epoch: 137 | Acc:  100| Loss:1.0711e-02 | 0m 0.34s
#
# 186.0 201.0
# VALID Epoch: 137 | Acc:   92| Loss:2.5896e-01 | 0m 0.68s
#
# ##################################################
# 802.0 802.0
# TRAIN Epoch: 138 | Acc:  100| Loss:1.6136e-02 | 0m 0.30s
#
# 186.0 201.0
# VALID Epoch: 138 | Acc:   92| Loss:2.5715e-01 | 0m 0.63s
#
# ##################################################
# 802.0 802.0
# TRAIN Epoch: 139 | Acc:  100| Loss:7.9591e-03 | 0m 0.38s
#
# 185.0 201.0
# VALID Epoch: 139 | Acc:   92| Loss:2.4390e-01 | 0m 0.69s
#
# ##################################################
# 802.0 802.0
# TRAIN Epoch: 140 | Acc:  100| Loss:1.4732e-02 | 0m 0.34s
#
# 186.0 201.0
# VALID Epoch: 140 | Acc:   92| Loss:2.6212e-01 | 0m 0.67s
#
# ##################################################
# 802.0 802.0
# TRAIN Epoch: 141 | Acc:  100| Loss:1.4583e-02 | 0m 0.35s
#
# 186.0 201.0
# VALID Epoch: 141 | Acc:   92| Loss:2.5560e-01 | 0m 0.66s
#
# ##################################################
# 802.0 802.0
# TRAIN Epoch: 142 | Acc:  100| Loss:7.4086e-03 | 0m 0.34s
#
# 186.0 201.0
# VALID Epoch: 142 | Acc:   92| Loss:2.4782e-01 | 0m 0.67s
#
# ##################################################
# 802.0 802.0
# TRAIN Epoch: 143 | Acc:  100| Loss:1.4236e-02 | 0m 0.36s
#
# 186.0 201.0
# VALID Epoch: 143 | Acc:   92| Loss:2.6212e-01 | 0m 0.67s
#
# ##################################################
# 802.0 802.0
# TRAIN Epoch: 144 | Acc:  100| Loss:6.9853e-03 | 0m 0.33s
#
# 186.0 201.0
# VALID Epoch: 144 | Acc:   92| Loss:2.4538e-01 | 0m 0.67s
#
# ##################################################
# 802.0 802.0
# TRAIN Epoch: 145 | Acc:  100| Loss:1.1726e-02 | 0m 0.36s
#
# 186.0 201.0
# VALID Epoch: 145 | Acc:   92| Loss:2.4722e-01 | 0m 0.66s
#
# ##################################################
# 802.0 802.0
# TRAIN Epoch: 146 | Acc:  100| Loss:1.4952e-02 | 0m 0.40s
#
# 186.0 201.0
# VALID Epoch: 146 | Acc:   92| Loss:2.5076e-01 | 0m 0.70s
#
# ##################################################
# 802.0 802.0
# TRAIN Epoch: 147 | Acc:  100| Loss:9.6238e-03 | 0m 0.30s
#
# 186.0 201.0
# VALID Epoch: 147 | Acc:   92| Loss:2.6150e-01 | 0m 0.65s
#
# ##################################################
# 802.0 802.0
# TRAIN Epoch: 148 | Acc:  100| Loss:1.1368e-02 | 0m 0.32s
#
# 186.0 201.0
# VALID Epoch: 148 | Acc:   92| Loss:2.6729e-01 | 0m 0.67s
#
# ##################################################
# 802.0 802.0
# TRAIN Epoch: 149 | Acc:  100| Loss:8.2095e-03 | 0m 0.33s
#
# 184.0 201.0
# VALID Epoch: 149 | Acc:   91| Loss:2.3665e-01 | 0m 0.69s
#
# ##################################################
# 802.0 802.0
# TRAIN Epoch: 150 | Acc:  100| Loss:9.4107e-03 | 0m 0.30s
#
# 186.0 201.0
# VALID Epoch: 150 | Acc:   92| Loss:2.7678e-01 | 0m 0.62s
#
# ##################################################
# 802.0 802.0
# TRAIN Epoch: 151 | Acc:  100| Loss:1.5701e-02 | 0m 0.40s
#
# 187.0 201.0
# VALID Epoch: 151 | Acc:   93| Loss:2.5571e-01 | 0m 0.74s
#
# ##################################################
# 802.0 802.0
# TRAIN Epoch: 152 | Acc:  100| Loss:1.2459e-02 | 0m 0.32s
#
# 186.0 201.0
# VALID Epoch: 152 | Acc:   92| Loss:2.5185e-01 | 0m 0.64s
#
# ##################################################
# 802.0 802.0
# TRAIN Epoch: 153 | Acc:  100| Loss:6.6541e-03 | 0m 0.38s
#
# 186.0 201.0
# VALID Epoch: 153 | Acc:   92| Loss:2.7375e-01 | 0m 0.69s
#
# ##################################################
# 802.0 802.0
# TRAIN Epoch: 154 | Acc:  100| Loss:6.2300e-03 | 0m 0.37s
#
# 184.0 201.0
# VALID Epoch: 154 | Acc:   91| Loss:2.4390e-01 | 0m 0.70s
#
# ##################################################
# 802.0 802.0
# TRAIN Epoch: 155 | Acc:  100| Loss:7.1272e-03 | 0m 0.35s
#
# 185.0 201.0
# VALID Epoch: 155 | Acc:   92| Loss:2.8913e-01 | 0m 0.72s
#
# ##################################################
# 802.0 802.0
# TRAIN Epoch: 156 | Acc:  100| Loss:9.8905e-03 | 0m 0.37s
#
# 185.0 201.0
# VALID Epoch: 156 | Acc:   92| Loss:2.4107e-01 | 0m 0.68s
#
# ##################################################
# 802.0 802.0
# TRAIN Epoch: 157 | Acc:  100| Loss:7.5125e-03 | 0m 0.35s
#
# 187.0 201.0
# VALID Epoch: 157 | Acc:   93| Loss:2.5944e-01 | 0m 0.67s
#
# ##################################################
# 802.0 802.0
# TRAIN Epoch: 158 | Acc:  100| Loss:1.2098e-02 | 0m 0.34s
#
# 186.0 201.0
# VALID Epoch:
-03 | 0m 0.33s
#
# 187.0 201.0
# VALID Epoch: 219 | Acc:   93| Loss:2.7252e-01 | 0m 0.62s
#
# ##################################################
# 802.0 802.0
# TRAIN Epoch: 220 | Acc:  100| Loss:6.1256e-03 | 0m 0.35s
#
# 187.0 201.0
# VALID Epoch: 220 | Acc:   93| Loss:2.6180e-01 | 0m 0.71s
#
# ##################################################
# 802.0 802.0
# TRAIN Epoch: 221 | Acc:  100| Loss:3.5136e-03 | 0m 0.34s
#
# 187.0 201.0
# VALID Epoch: 221 | Acc:   93| Loss:2.6851e-01 | 0m 0.66s
#
# ##################################################
# 802.0 802.0
# TRAIN Epoch: 222 | Acc:  100| Loss:2.5558e-03 | 0m 0.36s
#
# 187.0 201.0
# VALID Epoch: 222 | Acc:   93| Loss:2.6899e-01 | 0m 0.72s
#
# ##################################################
# 802.0 802.0
# TRAIN Epoch: 223 | Acc:  100| Loss:4.3299e-03 | 0m 0.35s
#
# 185.0 201.0
# VALID Epoch: 223 | Acc:   92| Loss:2.6632e-01 | 0m 0.70s
#
# ##################################################
# 802.0 802.0
# TRAIN Epoch: 224 | Acc:  100| Loss:4.6527e-03 | 0m 0.40s
#
# 187.0 201.0
# VALID Epoch: 224 | Acc:   93| Loss:2.6571e-01 | 0m 0.71s
#
# ##################################################
# 802.0 802.0
# TRAIN Epoch: 225 | Acc:  100| Loss:2.1059e-03 | 0m 0.36s
#
# 186.0 201.0
# VALID Epoch: 225 | Acc:   92| Loss:2.7806e-01 | 0m 0.70s
#
# ##################################################
# 802.0 802.0
# TRAIN Epoch: 226 | Acc:  100| Loss:3.1480e-03 | 0m 0.34s
#
# 187.0 201.0
# VALID Epoch: 226 | Acc:   93| Loss:2.6607e-01 | 0m 0.70s
#
# ##################################################
# 802.0 802.0
# TRAIN Epoch: 227 | Acc:  100| Loss:3.8230e-03 | 0m 0.33s
#
# 187.0 201.0
# VALID Epoch: 227 | Acc:   93| Loss:2.6988e-01 | 0m 0.68s
#
# ##################################################
# 802.0 802.0
# TRAIN Epoch: 228 | Acc:  100| Loss:4.0347e-03 | 0m 0.30s
#
# 187.0 201.0
# VALID Epoch: 228 | Acc:   93| Loss:2.6386e-01 | 0m 0.62s
#
# ##################################################
# 802.0 802.0
# TRAIN Epoch: 229 | Acc:  100| Loss:2.9740e-03 | 0m 0.34s
#
# 186.0 201.0
# VALID Epoch: 229 | Acc:   92| Loss:2.7206e-01 | 0m 0.69s
#
# ##################################################
# 802.0 802.0
# TRAIN Epoch: 230 | Acc:  100| Loss:3.1703e-03 | 0m 0.37s
#
# 185.0 201.0
# VALID Epoch: 230 | Acc:   92| Loss:2.7000e-01 | 0m 0.69s
#
# ##################################################
# 802.0 802.0
# TRAIN Epoch: 231 | Acc:  100| Loss:1.6675e-03 | 0m 0.37s
#
# 186.0 201.0
# VALID Epoch: 231 | Acc:   92| Loss:2.7717e-01 | 0m 0.66s
#
# ##################################################
# 802.0 802.0
# TRAIN Epoch: 232 | Acc:  100| Loss:1.6985e-03 | 0m 0.35s
#
# 185.0 201.0
# VALID Epoch: 232 | Acc:   92| Loss:2.6670e-01 | 0m 0.67s
#
# ##################################################
# 802.0 802.0
# TRAIN Epoch: 233 | Acc:  100| Loss:3.7005e-03 | 0m 0.33s
#
# 186.0 201.0
# VALID Epoch: 233 | Acc:   92| Loss:2.6819e-01 | 0m 0.70s
#
# ##################################################
# 802.0 802.0
# TRAIN Epoch: 234 | Acc:  100| Loss:4.4941e-03 | 0m 0.34s
#
# 185.0 201.0
# VALID Epoch: 234 | Acc:   92| Loss:2.6145e-01 | 0m 0.68s
#
# ##################################################
# 802.0 802.0
# TRAIN Epoch: 235 | Acc:  100| Loss:2.5275e-03 | 0m 0.32s
#
# 187.0 201.0
# VALID Epoch: 235 | Acc:   93| Loss:2.8341e-01 | 0m 0.66s
#
# ##################################################
# 802.0 802.0
# TRAIN Epoch: 236 | Acc:  100| Loss:3.1514e-03 | 0m 0.34s
#
# 185.0 201.0
# VALID Epoch: 236 | Acc:   92| Loss:2.6258e-01 | 0m 0.64s
#
# ##################################################
# 802.0 802.0
# TRAIN Epoch: 237 | Acc:  100| Loss:3.6226e-03 | 0m 0.32s
#
# 186.0 201.0
# VALID Epoch: 237 | Acc:   92| Loss:2.7565e-01 | 0m 0.64s
#
# ##################################################
# 802.0 802.0
# TRAIN Epoch: 238 | Acc:  100| Loss:2.8864e-03 | 0m 0.39s
#
# 185.0 201.0
# VALID Epoch: 238 | Acc:   92| Loss:2.6305e-01 | 0m 0.70s
#
# ##################################################
# 802.0 802.0
# TRAIN Epoch: 239 | Acc:  100| Loss:2.3832e-03 | 0m 0.36s
#
# 186.0 201.0
# VALID Epoch: 239 | Acc:   92| Loss:2.7405e-01 | 0m 0.68s
#
# ##################################################
# 802.0 802.0
# TRAIN Epoch: 240 | Acc:  100| Loss:3.5459e-03 | 0m 0.33s
#
# 184.0 201.0
# VALID Epoch: 240 | Acc:   91| Loss:2.7166e-01 | 0m 0.69s
#
# ##################################################
# 802.0 802.0
# TRAIN Epoch: 241 | Acc:  100| Loss:2.5366e-03 | 0m 0.35s
#
# 185.0 201.0
# VALID Epoch: 241 | Acc:   92| Loss:2.7814e-01 | 0m 0.68s
#
# ##################################################
# 802.0 802.0
# TRAIN Epoch: 242 | Acc:  100| Loss:4.6531e-03 | 0m 0.33s
#
# 186.0 201.0
# VALID Epoch: 242 | Acc:   92| Loss:2.7064e-01 | 0m 0.64s
#
# ##################################################
# 802.0 802.0
# TRAIN Epoch: 243 | Acc:  100| Loss:2.8355e-03 | 0m 0.33s
#
# 185.0 201.0
# VALID Epoch: 243 | Acc:   92| Loss:2.6483e-01 | 0m 0.71s
#
# ##################################################
# 802.0 802.0
# TRAIN Epoch: 244 | Acc:  100| Loss:2.8805e-03 | 0m 0.36s
#
# 186.0 201.0
# VALID Epoch: 244 | Acc:   92| Loss:2.7190e-01 | 0m 0.69s
#
# ##################################################
# 802.0 802.0
# TRAIN Epoch: 245 | Acc:  100| Loss:3.1564e-03 | 0m 0.36s
#
# 186.0 201.0
# VALID Epoch: 245 | Acc:   92| Loss:2.7509e-01 | 0m 0.69s
#
# ##################################################
# 802.0 802.0
# TRAIN Epoch: 246 | Acc:  100| Loss:2.5705e-03 | 0m 0.39s
#
# 185.0 201.0
# VALID Epoch: 246 | Acc:   92| Loss:2.6553e-01 | 0m 0.73s
#
# ##################################################
# 802.0 802.0
# TRAIN Epoch:
-04 | 0m 0.34s
#
# 186.0 201.0
# VALID Epoch: 476 | Acc:   92| Loss:2.8777e-01 | 0m 0.66s
#
# ##################################################
# 802.0 802.0
# TRAIN Epoch: 477 | Acc:  100| Loss:4.6709e-04 | 0m 0.34s
#
# 186.0 201.0
# VALID Epoch: 477 | Acc:   92| Loss:2.9189e-01 | 0m 0.73s
#
# ##################################################
# 802.0 802.0
# TRAIN Epoch: 478 | Acc:  100| Loss:4.3098e-04 | 0m 0.35s
#
# 187.0 201.0
# VALID Epoch: 478 | Acc:   93| Loss:2.9711e-01 | 0m 0.66s
#
# ##################################################
# 802.0 802.0
# TRAIN Epoch: 479 | Acc:  100| Loss:3.7154e-04 | 0m 0.33s
#
# 186.0 201.0
# VALID Epoch: 479 | Acc:   92| Loss:2.8502e-01 | 0m 0.67s
#
# ##################################################
# 802.0 802.0
# TRAIN Epoch: 480 | Acc:  100| Loss:3.4357e-04 | 0m 0.33s
#
# 187.0 201.0
# VALID Epoch: 480 | Acc:   93| Loss:2.9632e-01 | 0m 0.65s
#
# ##################################################
# 802.0 802.0
# TRAIN Epoch: 481 | Acc:  100| Loss:4.1358e-04 | 0m 0.31s
#
# 186.0 201.0
# VALID Epoch: 481 | Acc:   92| Loss:2.8672e-01 | 0m 0.65s
#
# ##################################################
# 802.0 802.0
# TRAIN Epoch: 482 | Acc:  100| Loss:3.5861e-04 | 0m 0.32s
#
# 187.0 201.0
# VALID Epoch: 482 | Acc:   93| Loss:2.9697e-01 | 0m 0.64s
#
# ##################################################
# 802.0 802.0
# TRAIN Epoch: 483 | Acc:  100| Loss:3.3956e-04 | 0m 0.33s
#
# 186.0 201.0
# VALID Epoch: 483 | Acc:   92| Loss:2.9004e-01 | 0m 0.67s
#
# ##################################################
# 802.0 802.0
# TRAIN Epoch: 484 | Acc:  100| Loss:3.0001e-04 | 0m 0.35s
#
# 186.0 201.0
# VALID Epoch: 484 | Acc:   92| Loss:2.9396e-01 | 0m 0.65s
#
# ##################################################
# 802.0 802.0
# TRAIN Epoch: 485 | Acc:  100| Loss:2.6580e-04 | 0m 0.34s
#
# 186.0 201.0
# VALID Epoch: 485 | Acc:   92| Loss:2.9477e-01 | 0m 0.66s
#
# ##################################################
# 802.0 802.0
# TRAIN Epoch: 486 | Acc:  100| Loss:2.9182e-04 | 0m 0.34s
#
# 186.0 201.0
# VALID Epoch: 486 | Acc:   92| Loss:2.9397e-01 | 0m 0.67s
#
# ##################################################
# 802.0 802.0
# TRAIN Epoch: 487 | Acc:  100| Loss:2.1579e-04 | 0m 0.35s
#
# 186.0 201.0
# VALID Epoch: 487 | Acc:   92| Loss:2.9496e-01 | 0m 0.67s
#
# ##################################################
# 802.0 802.0
# TRAIN Epoch: 488 | Acc:  100| Loss:2.8423e-04 | 0m 0.33s
#
# 186.0 201.0
# VALID Epoch: 488 | Acc:   92| Loss:2.8895e-01 | 0m 0.62s
#
# ##################################################
# 802.0 802.0
# TRAIN Epoch: 489 | Acc:  100| Loss:4.2018e-04 | 0m 0.33s
#
# 186.0 201.0
# VALID Epoch: 489 | Acc:   92| Loss:2.9534e-01 | 0m 0.67s
#
# ##################################################
# 802.0 802.0
# TRAIN Epoch: 490 | Acc:  100| Loss:2.2170e-04 | 0m 0.35s
#
# 186.0 201.0
# VALID Epoch: 490 | Acc:   92| Loss:2.9494e-01 | 0m 0.68s
#
# ##################################################
# 802.0 802.0
# TRAIN Epoch: 491 | Acc:  100| Loss:2.3957e-04 | 0m 0.37s
#
# 186.0 201.0
# VALID Epoch: 491 | Acc:   92| Loss:2.9980e-01 | 0m 0.68s
#
# ##################################################
# 802.0 802.0
# TRAIN Epoch: 492 | Acc:  100| Loss:2.9624e-04 | 0m 0.36s
#
# 186.0 201.0
# VALID Epoch: 492 | Acc:   92| Loss:2.8827e-01 | 0m 0.67s
#
# ##################################################
# 802.0 802.0
# TRAIN Epoch: 493 | Acc:  100| Loss:2.7968e-04 | 0m 0.36s
#
# 186.0 201.0
# VALID Epoch: 493 | Acc:   92| Loss:2.9949e-01 | 0m 0.67s
#
# ##################################################
# 802.0 802.0
# TRAIN Epoch: 494 | Acc:  100| Loss:3.2476e-04 | 0m 0.33s
#
# 186.0 201.0
# VALID Epoch: 494 | Acc:   92| Loss:2.9316e-01 | 0m 0.64s
#
# ##################################################
# 802.0 802.0
# TRAIN Epoch: 495 | Acc:  100| Loss:3.0188e-04 | 0m 0.33s
#
# 186.0 201.0
# VALID Epoch: 495 | Acc:   92| Loss:2.9317e-01 | 0m 0.64s
#
# ##################################################
# 802.0 802.0
# TRAIN Epoch: 496 | Acc:  100| Loss:3.7756e-04 | 0m 0.33s
#
# 186.0 201.0
# VALID Epoch: 496 | Acc:   92| Loss:3.0150e-01 | 0m 0.64s
#
# ##################################################
# 802.0 802.0
# TRAIN Epoch: 497 | Acc:  100| Loss:3.4942e-04 | 0m 0.35s
#
# 186.0 201.0
# VALID Epoch: 497 | Acc:   92| Loss:2.9755e-01 | 0m 0.72s
#
# ##################################################
# 802.0 802.0
# TRAIN Epoch: 498 | Acc:  100| Loss:5.1613e-04 | 0m 0.38s
#
# 186.0 201.0
# VALID Epoch: 498 | Acc:   92| Loss:2.9635e-01 | 0m 0.67s
#
# ##################################################
# 802.0 802.0
# TRAIN Epoch: 499 | Acc:  100| Loss:2.4339e-04 | 0m 0.34s
#
# 186.0 201.0
# VALID Epoch: 499 | Acc:   92| Loss:3.0268e-01 | 0m 0.67s

# %%
writer.add_hparams(hparam_dict={'batch_size':batch_size}, metric_dict={'loss':np.array(metrics['loss_train'][0][0]).reshape(-1)})

# %%
len(metrics['loss_train'])
# Out:
# 20

# %% [markdown]
# FLUID INTELLIGENCE
